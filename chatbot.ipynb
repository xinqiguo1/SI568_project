# %%
import openai
openai.api_key = "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"

def summarize_text(text, max_tokens):
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=f"Please summarize the following text:\n\n{text}\n\nSummary:",
        max_tokens=max_tokens
    )

    return response.choices[0].text.strip()

# Example usage
text_to_summarize = """
The quick brown fox jumped over the lazy dog. The dog didn't seem to notice, but the fox was proud of its accomplishment. 
"""
summary = summarize_text(text_to_summarize, 20)
print(summary)
# Out:
# The quick brown fox jumped over the lazy dog. The fox was proud of its accomplishment,

# %%
import openai
# Set the OpenAI API key for authentication
openai.api_key = "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"

def chatbot(prompt):
    """
    This function takes a prompt string as an argument and sends it to OpenAI's GPT-3 API to generate a text response.
    Args:
    prompt (str): The prompt string for which we want to generate a response.

    Returns:
    str: The response generated by OpenAI's GPT-3 API.
    """
    
    # Call the OpenAI API to generate a response based on the given prompt
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        max_tokens=1024,
        n=1,
        stop=None,
        temperature=0.5,
    )

    # Return the first and only response choice as a string with leading/trailing whitespaces removed
    return response.choices[0].text.strip()

# main program
if __name__ == "__main__":
    
    # Start the chatbot program only if the user enters 1, otherwise exit
    start = int(input("This is a program to compare two items you are deciding to buy or know about."+
                      " If you are ready, please enter 1"))
    if start != 1:
        print("Exiting chatbot...")
        
    # Start the chatbot program until the user enters "exit" or "quit"
    while start:
        user_input1 = input("What's the first item you want to compare, if no, please enter exit. ")
        user_input2 = input("What's the second item you want to compare, if no, please enter exit. ")

        if (user_input1.lower() in ["exit", "quit"]) or (user_input2.lower() in ["exit", "quit"]):
            print("Exiting chatbot...")
            break

        # Generate a prompt for the chatbot based on user's inputs
        prompt=f"Please provide the comparison between:\n\n{user_input1}\n\n and\n\n{user_input2}\n\n"
        
        # Call the chatbot function to generate a response based on the prompt    
        response = chatbot(prompt)
        
        # Print the response generated by the chatbot
        print(f"{response}")

        # Ask the user if they want to explore more comparisons or exit
        keep = int(input("If you like to explore more, please enter 1. Otherwise, please enter 0 to exit "))
        
        # If the user wants to explore more, generate another prompt for the chatbot based on user's inputs
        if keep == 1:
            prompt=f"Please provide more about the comparison between:\n\n{user_input1}\n\n and\n\n{user_input2}\n\n"
            response = chatbot(prompt)
            print(f"{response}")
        else:
            # If the user doesn't want to explore more, exit the program
            print("Exiting chatbot...")
            break
            
        # Ask the user if they want to compare other items or exit
        start = int(input("If you like to play another comparision, please enter 1."+
                          "Otherwise, please enter 0 to exit "))
# Out:
# This is a program to compare two items you are deciding to buy or know about. If you are ready, please enter 10
# Exiting chatbot...

# %%
keep
# Out:
# '1'
